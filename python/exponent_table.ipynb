# %%
import math

# %%
a = ['{0:0{1}}'.format(round(math.pow(10,18) * math.pow(2, math.pow(10,-18) * math.pow(2, i))), 16)
     for i in range(64)]
a
# Out:
# ['1000000000000000000',
#  '1000000000000000000',
#  '1000000000000000000',
#  '1000000000000000000',
#  '1000000000000000000',
#  '1000000000000000000',
#  '1000000000000000000',
#  '1000000000000000000',
#  '1000000000000000256',
#  '1000000000000000384',
#  '1000000000000000640',
#  '1000000000000001280',
#  '1000000000000002944',
#  '1000000000000005760',
#  '1000000000000011264',
#  '1000000000000022656',
#  '1000000000000045568',
#  '1000000000000090880',
#  '1000000000000181632',
#  '1000000000000363520',
#  '1000000000000726784',
#  '1000000000001453696',
#  '1000000000002907264',
#  '1000000000005814400',
#  '1000000000011629184',
#  '1000000000023258112',
#  '1000000000046516352',
#  '1000000000093032704',
#  '1000000000186065408',
#  '1000000000372130560',
#  '1000000000744261120',
#  '1000000001488522240',
#  '1000000002977044352',
#  '1000000005954088960',
#  '1000000011908178048',
#  '1000000023816355968',
#  '1000000047632712704',
#  '1000000095265427584',
# ...
